# %%
from scipy.stats import uniform
dist = uniform.rvs(0,5,size=100)

# %%
import numpy as np
import matplotlib.pyplot as plt
# Example numpy array
# data = np.random.randn(1000)
data = dist
def plot(data):

    # Plotting the histogram of the numpy array
    plt.figure(figsize=(10, 6))
    plt.hist(data, bins=30, alpha=0.7, edgecolor='black')

    # Adding labels and title
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Distribution of the NumPy Array')
    plt.show()
plot(data)

# %%
# Example numpy array
data = np.random.randn(1000)
def plot_seaborn(data):
    # Plotting the KDE of the numpy array
    plt.figure(figsize=(10, 6))
    sns.kdeplot(data)

    # Adding labels and title
    plt.xlabel('Value')
    plt.title('KDE Plot of the NumPy Array')
    plt.show()
plot_seaborn(data)

# %%
data_binomial = np.random.binomial(n=10, p=0.5, size=50)
plot(data_binomial)

# %%
data_poisson = np.random.poisson(lam=5, size=10000)
plot(data_poisson)

# %%
data_hypergeometric = np.random.hypergeometric(ngood=30, nbad=70, nsample=10, size=50)
plot(data_hypergeometric)

# %%
data_normal = np.random.normal(loc=0, scale=1, size=100000)
plot(data_normal)

# %%
data_exponential = np.random.exponential(scale=1.0, size=1000)
plot(data_exponential)

# %%
data_student = np.random.standard_t(df=10, size=100)
plot(data_student)
